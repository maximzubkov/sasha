# %%
import json
import os
import pandas as pd

# %% [markdown]
# ### Objects

# %%
df = pd.read_json('./old/objects.json').T[['get_year',  'hall', 'litra', 'm_parent_id', 'masterpiece', 'material', 'name', 'origplace','paint_school', 'path', 'period', 'producein', 'restor', 'seakeys', 'show_in_collection', 'show_in_hall', 'size', 'text', 'type', 'year']]

# %%
df_ru = df.copy()
df_ru["litra"] = df_ru['litra'].apply(lambda x: x["ru"])
df_ru["material"] = df_ru['material'].apply(lambda x: x["ru"])
df_ru["name"] = df_ru['name'].apply(lambda x: x["ru"])
df_ru["paint_school"] = df_ru['paint_school'].apply(lambda x: x["ru"] if x else "")
df_ru["producein"] = df_ru['producein'].apply(lambda x: x["ru"])
df_ru["restor"] = df_ru['restor'].apply(lambda x: x["ru"])
df_ru["seakeys"] = df_ru['seakeys'].apply(lambda x: x["ru"])
df_ru["size"] = df_ru['size'].apply(lambda x: x["ru"])
df_ru["text"] = df_ru['text'].apply(lambda x: x["ru"])
df_ru["type"] = df_ru['type'].apply(lambda x: x["ru"])
df_ru["period_text"] = df_ru['period'].apply(lambda x: x["text"]["ru"] if x else "")
df_ru["period_name"] = df_ru['period'].apply(lambda x: x["name"]["ru"] if x else "")

# %%
df_eng = df.copy()
df_eng["litra"] = df_eng['litra'].apply(lambda x: x["en"])
df_eng["material"] = df_eng['material'].apply(lambda x: x["en"])
df_eng["name"] = df_eng['name'].apply(lambda x: x["en"])
df_eng["paint_school"] = df_eng['paint_school'].apply(lambda x: x["en"] if x else "")
df_eng["producein"] = df_eng['producein'].apply(lambda x: x["en"])
df_eng["restor"] = df_eng['restor'].apply(lambda x: x["en"])
df_eng["seakeys"] = df_eng['seakeys'].apply(lambda x: x["en"])
df_eng["size"] = df_eng['size'].apply(lambda x: x["en"])
df_eng["text"] = df_eng['text'].apply(lambda x: x["en"])
df_eng["type"] = df_eng['type'].apply(lambda x: x["en"])
df_eng["period_text"] = df_eng['period'].apply(lambda x: x["text"]["en"] if x else "")
df_eng["period_name"] = df_eng['period'].apply(lambda x: x["name"]["en"] if x else "")

# %%
os.getcwd()
# Out:
# '/Users/maximzubkov/Desktop/Programming/sasha/src/data'

# %%
df_ru.T.to_json("./parsed/objects_rus.json")
df_eng.T.to_json("./parsed/objects_eng.json")

# %% [markdown]
# ### Events

# %%
df = pd.read_json('./old/events.json').T

# %%
df.columns
# Out:
# Index(['ab_event', 'addtext', 'age', 'audioguide', 'building', 'circ_img',
#        'connect', 'date', 'dateBegin', 'dateEnd', 'files', 'gallery', 'halls',
#        'headimg', 'img_header', 'm_parent_id', 'mapurl', 'mediaguide', 'name',
#        'path', 'price', 'seakeys', 'searcha', 'shop', 'sponsors', 'text',
#        'ticket', 'type', 'within'],
#       dtype='object')

# %%
df[[""]]
# Out:
#       ab_event               addtext age  \
# 11421           {'ru': '', 'en': ''}
# 11540           {'ru': '', 'en': ''}
# 11468           {'ru': '', 'en': ''}
# 12173           {'ru': '', 'en': ''}
# 11540                          {'0': '121'}
# 11468                          {'0': '116'}
# 12173                          {'0': '121'}
# 12040                          {'0': '116'}
# 12084                          {'0': '119'}
# 12426                          {'0': '116'}
# 12015                          {'0': '119'}
# 12463                          {'0': '116'}
# 12065                          {'0': '119'}
# 12066                          {'0': '119'}
# 12464                          {'0': '116'}
# 12046                          {'0': '119'}
# 12438  {'0': '116', '1': '117', '2': '121'}
# 12442                          {'0': '116'}
# 12466                          {'0': '119'}
# 12174                          {'0': '121'}
# 12058                          {'0': '119'}
# 12059                          {'0': '119'}
# 12085                          {'0': '119'}
# 12357                          {'0': '116'}
# 12016                          {'0': '119'}
# 12067                          {'0': '119'}
# 12047                          {'0': '119'}
# 12175                          {'0': '121'}
# 12465                          {'0': '116'}
# 12060                          {'0': '119'}
# 12086                          {'0': '119'}
# 12017                          {'0': '119'}
# 12068                          {'0': '119'}
# 12358                          {'0': '116'}
# 12048                          {'0': '119'}
# 12061                          {'0': '119'}
# 12087                          {'0': '119'}
# 12018                          {'0': '119'}
# 12069                          {'0': '119'}
# 12049                          {'0': '119'}
#
#                                                 circ_img connect  \
# 11421  {'id01': '/events/archive/2019/exhibitions/lou...
# 11540  {'id01': '/events/archive/2019/others/flat/115...
# 11468  {'id01': '/events/archive/2019/exhibitions/jor...
# 12173  {'id01': '/events/archive/2019/others/flat/28_...
# 12040                                                NaN
# 12084  {'id01': '/events/archive/2019/2019-2020_ab13/...
# 12426  {'id01': '/events/archive/2019/exhibitions/jor...
# 12015  {'id01': '/events/archive/2019/lections_2019-2...
# 12463  {'id01': '/events/archive/2019/exhibitions/jaz...
# 12065  {'id01': '/events/archive/2019/2019-2020_ab6/1...
# 12066  {'id01': '/events/archive/2019/2019-2020_ab6/3...
# 12464  {'id01': '/events/archive/2019/exhibitions/jaz...
# 12046  {'id01': '/events/archive/2019/2019-2020_ab3/4...
# 12438  {'id01': '/events/archive/2019/others/friday/1...
# 12442  {'id01': '/events/archive/2019/others/friday/0...
# 12466  {'id01': '/education/museyon/clubs/alumni/05_1...
# 12174  {'id01': '/events/archive/2019/others/flat/06_...
# 12058  {'id01': '/events/archive/2019/2019-2020_ab5/1...
# 12059  {'id01': '/events/archive/2019/2019-2020_ab5/8...
# 12085  {'id01': '/events/archive/2019/2019-2020_ab13/...
# 12357  {'id01': '/events/archive/2019/exhibitions/jor...
# 12016  {'id01': '/events/archive/2019/lections_2019-2...
# 12067  {'id01': '/events/archive/2019/2019-2020_ab6/1...
# 12047  {'id01': '/events/archive/2019/2019-2020_ab3/1...
# 12175  {'id01': '/events/archive/2019/others/flat/11_...
# 12465  {'id01': '/events/archive/2019/others/friday/1...
# 12060  {'id01': '/events/archive/2019/2019-2020_ab5/1...
# 12086  {'id01': '/events/archive/2019/2019-2020_ab13/...
# 12017  {'id01': '/events/archive/2019/lections_2019-2...
# 12068  {'id01': '/events/archive/2019/2019-2020_ab6/1...
# 12358  {'id01': '/events/archive/2019/exhibitions/jor...
# 12060  {'ru': '', 'en': ''}  2019-10-15 00:00:00  0000-00-00 00:00:00  ...
# 12086  {'ru': '', 'en': ''}  2019-10-15 00:00:00  0000-00-00 00:00:00  ...
# 12017  {'ru': '', 'en': ''}  2019-10-16 00:00:00  0000-00-00 00:00:00  ...
# 12068  {'ru': '', 'en': ''}  2019-10-17 00:00:00  0000-00-00 00:00:00  ...
# 12358  {'ru': '', 'en': ''}  2019-10-17 00:00:00  0000-00-00 00:00:00  ...
# 12048  {'ru': '', 'en': ''}  2019-10-18 00:00:00  0000-00-00 00:00:00  ...
# 12061  {'ru': '', 'en': ''}  2019-10-22 00:00:00  0000-00-00 00:00:00  ...
# 12087  {'ru': '', 'en': ''}  2019-10-22 00:00:00  0000-00-00 00:00:00  ...
# 12018  {'ru': '', 'en': ''}  2019-10-23 00:00:00  0000-00-00 00:00:00  ...
# 12069  {'ru': '', 'en': ''}  2019-10-24 00:00:00  0000-00-00 00:00:00  ...
# 12049  {'ru': '', 'en': ''}  2019-10-25 00:00:00  0000-00-00 00:00:00  ...
#
#                                                     path  \
# 11421  events/archive/2019/exhibitions/louisvuitton/i...
# 11540          events/archive/2019/others/flat/index.php
# 11468  events/archive/2019/exhibitions/jordaens/index...
# 12173    events/archive/2019/others/flat/28_09/index.php
# 12040     events/archive/2019/exhibitions/jazz/index.php
# 12084  events/archive/2019/2019-2020_ab13/1oct/index.php
# 12426  events/archive/2019/exhibitions/jordaens/01_10...
# 12015  events/archive/2019/lections_2019-2020/ab1/02_...
# 12463  events/archive/2019/exhibitions/jazz/02_10/ind...
# 12065        events/archive/2019/2019-2020_ab6/index.php
# 12066   events/archive/2019/2019-2020_ab6/3oct/index.php
# 12464  events/archive/2019/exhibitions/jazz/03_10/ind...
# 12046   events/archive/2019/2019-2020_ab3/4oct/index.php
# 12438        events/archive/2019/others/friday/index.php
# 12442  events/archive/2019/others/friday/04_10/index.php
# 12466     education/museyon/clubs/alumni/05_10/index.php
# 12174    events/archive/2019/others/flat/06_10/index.php
# 12058        events/archive/2019/2019-2020_ab5/index.php
# 12059   events/archive/2019/2019-2020_ab5/8oct/index.php
# 12085  events/archive/2019/2019-2020_ab13/8oct/index.php
# 12357  events/archive/2019/exhibitions/jordaens/08_10...
# 12016  events/archive/2019/lections_2019-2020/ab1/09_...
# 12067  events/archive/2019/2019-2020_ab6/10oct/index.php
# 12047  events/archive/2019/2019-2020_ab3/11oct/index.php
# 12175    events/archive/2019/others/flat/11_10/index.php
# 12465  events/archive/2019/others/friday/11_11/index.php
# 12060  events/archive/2019/2019-2020_ab5/15oct/index.php
# 12086  events/archive/2019/2019-2020_ab13/15oct/index...
# 12017  events/archive/2019/lections_2019-2020/ab1/16_...
# 12068  events/archive/2019/2019-2020_ab6/17oct/index.php
# 12358  events/archive/2019/exhibitions/jordaens/17_10...
# 12048  events/archive/2019/2019-2020_ab3/18oct/index.php
# 12061  events/archive/2019/2019-2020_ab5/22oct/index.php
# 12087  events/archive/2019/2019-2020_ab13/22oct/index...
# 12018  events/archive/2019/lections_2019-2020/ab1/23_...
# 12069  events/archive/2019/2019-2020_ab6/24oct/index.php
# 12049  events/archive/2019/2019-2020_ab3/25oct/index.php
#
#                                                    price  \
# 11421  {'ru': '<p>цена билета &mdash; 500 рублей,&nbs...
# 11540                               {'ru': '', 'en': ''}
# 11468                               {'ru': '', 'en': ''}
# 12173                               {'ru': '', 'en': ''}
# 12040                               {'ru': '', 'en': ''}
# 12084  {'ru': '<p>Цена полного билета&nbsp;&ndash; 65...
# 12426                               {'ru': '', 'en': ''}
# 12015  {'ru': '<p>Цена полного билета&nbsp;&ndash; 65...
# 12463  {'ru': '<p>полный билет &mdash; 650 рублей,&nb...
# 12065                               {'ru': '', 'en': ''}
# 12066  {'ru': '<p>Цена полного билета &ndash; 650 руб...
# 12464  {'ru': '<p>полный билет &mdash; 650 рублей,&nb...
# 12046  {'ru': '<p>Цена полного билета&nbsp;&ndash; 65...
# 12438                               {'ru': '', 'en': ''}
# 12442                               {'ru': '', 'en': ''}
# 12466                               {'ru': '', 'en': ''}
# 12174                               {'ru': '', 'en': ''}
# 12058                               {'ru': '', 'en': ''}
# 12059  {'ru': '<p>Цена полного билета &ndash; 650 руб...
# 12085  {'ru': '<p>Цена полного билета&nbsp;&ndash; 65...
# 12357                               {'ru': '', 'en': ''}
# 12016  {'ru': '<p>Цена полного билета &ndash; 650 руб...
# 12067  {'ru': '<p>Цена полного билета &ndash; 650 руб...
# 12047  {'ru': '<p>Цена полного билета&nbsp;&ndash; 65...
# 12175                               {'ru': '', 'en': ''}
# 12465                               {'ru': '', 'en': ''}
# 12060  {'ru': '<p>Цена полного билета &ndash; 650 руб...
# 12086  {'ru': '<p>Цена полного билета&nbsp;&ndash; 65...
# 12017  {'ru': '<p>Цена полного билета &ndash; 650 руб...
# 12068  {'ru': '<p>Цена полного билета &ndash; 650 руб...
# 12358                               {'ru': '', 'en': ''}
# 12048  {'ru': '<p>Цена полного билета &ndash; 650 руб...
# 12061  {'ru': '<p>Цена полного билета &ndash; 650 руб...
# 12087  {'ru': '<p>Цена полного билета&nbsp;&ndash; 65...
# 12018  {'ru': '<p>Цена полного билета &ndash; 650 руб...
# 12069  {'ru': '<p>Цена полного билета &ndash; 650 руб...
# 12049  {'ru': '<p>Цена полного билета &ndash; 650 руб...
#
#                     seakeys               searcha            shop  \
# 11421  {'ru': '', 'en': ''}  {'ru': '', 'en': ''}  {'0': '11855'}
# 11540  {'ru': '', 'en': ''}  {'ru': '', 'en': ''}
# 11468  {'ru': '', 'en': ''}  {'ru': '', 'en': ''}
# 12173  {'ru': '', 'en': ''}  {'ru': '', 'en': ''}
# 12040  {'ru': '', 'en': ''}  {'ru': '', 'en': ''}
# 12084  {'ru': '', 'en': ''}  {'ru': '', 'en': ''}
# 12426  {'ru': '', 'en': ''}  {'ru': '', 'en': ''}
# 12015  {'ru': '', 'en': ''}  {'ru': '', 'en': ''}
# 12463  {'ru': '', 'en': ''}  {'ru': '', 'en': ''}
# 12065  {'ru': '', 'en': ''}  {'ru': '', 'en': ''}
# 12066  {'ru': '', 'en': ''}  {'ru': '', 'en': ''}
# 12464  {'ru': '', 'en': ''}  {'ru': '', 'en': ''}
# 12046  {'ru': '', 'en': ''}  {'ru': '', 'en': ''}
# 12438  {'ru': '', 'en': ''}  {'ru': '', 'en': ''}
# 12442  {'ru': '', 'en': ''}  {'ru': '', 'en': ''}
# 12466  {'ru': '', 'en': ''}  {'ru': '', 'en': ''}
# 12174  {'ru': '', 'en': ''}  {'ru': '', 'en': ''}
# 12058  {'ru': '', 'en': ''}  {'ru': '', 'en': ''}
# 12059  {'ru': '', 'en': ''}  {'ru': '', 'en': ''}
# 12085  {'ru': '', 'en': ''}  {'ru': '', 'en': ''}
# 12357  {'ru': '', 'en': ''}  {'ru': '', 'en': ''}
# 12016  {'ru': '', 'en': ''}  {'ru': '', 'en': ''}
# 12067  {'ru': '', 'en': ''}  {'ru': '', 'en': ''}
# 12047  {'ru': '', 'en': ''}  {'ru': '', 'en': ''}
# 12175  {'ru': '', 'en': ''}  {'ru': '', 'en': ''}
# 12465  {'ru': '', 'en': ''}  {'ru': '', 'en': ''}
# 12060  {'ru': '', 'en': ''}  {'ru': '', 'en': ''}
# 12086  {'ru': '', 'en': ''}  {'ru': '', 'en': ''}
# 12017  {'ru': '', 'en': ''}  {'ru': '', 'en': ''}
# 12068  {'ru': '', 'en': ''}  {'ru': '', 'en': ''}
# 12358  {'ru': '', 'en': ''}  {'ru': '', 'en': ''}
# 12048  {'ru': '', 'en': ''}  {'ru': '', 'en': ''}
# 12061  {'ru': '', 'en': ''}  {'ru': '', 'en': ''}
# 12087  {'ru': '', 'en': ''}  {'ru': '', 'en': ''}
# 12018  {'ru': '', 'en': ''}  {'ru': '', 'en': ''}
# 12069  {'ru': '', 'en': ''}  {'ru': '', 'en': ''}
# 12049  {'ru': '', 'en': ''}  {'ru': '', 'en': ''}
#
#                                                 sponsors  \
# 11421  {'1': {'0': '11843', 'spcategory': {'ru': 'Спо...
# 11540
# 11468  {'1': {'0': '361', 'spcategory': {'ru': 'Генер...
# 12173
# 12040
# 12084
# 12426
# 12015
# 12463
# 12065
# 12066
# 12464
# 12046
# 12438
# 12442
# 12466
# 12174
# 12058
# 12059
# 12085
# 12357
# 12016
# 12067
# 12047
# 12175
# 12465
# 12060
# 12086
# 12017
# 12068
# 12358
# 12048
# 12061
# 12087
# 12018
# 12069
# 12049
#
#                                                     text  \
# 11421  {'ru': '<p><a href="https://pushkinmuseum.art/...
# 11540  {'ru': '<p>В новом сезоне известные музыканты ...
# 11468  {'ru': '<p>ГМИИ им. А.&nbsp;С. Пушкина предста...
# 12173  {'ru': '<p>28 сентября лауреаты международных ...
# 12040  {'ru': '<p><em>Новая выставка ГМИИ им. А.С. Пу...
# 12084  {'ru': '<p>Лекцию читает доцент РГГУ, кандидат...
# 12426  {'ru': '<p>В своей лекции доктор Йост Вандер А...
# 12015  {'ru': '<p>Лекцию читает кандидат искусствовед...
# 12463  {'ru': '<p><em>Икаты</em>&nbsp;Средней Азии &n...
# 12065  {'ru': '<p>Во второй половине XIX века в европ...
# 12066  {'ru': '<p>Лекцию читает научный сотрудник ГМИ...
# 12464  {'ru': '<p><strong>Елена Царёва</strong>, веду...
# 12046  {'ru': '<p>Лекцию читает кандидат искусствовед...
# 12438  {'ru': '<p>4 октября 2019 года ГМИИ им. А.С. П...
# 12442  {'ru': '<p><strong>Главное здание. Волхонка, 1...
# 12466  {'ru': '<p><em>Дмитрий Гутов, художник, теорет...
# 12174  {'ru': '<p>В программу сольного концерта лауре...
# 12058  {'ru': '<p>В начале XVII века Италия продолжал...
# 12059  {'ru': '<p>Лекцию читает научный сотрудник ГМИ...
# 12085  {'ru': '<p>Лекцию читает преподаватель факульт...
# 12357  {'ru': '<p>Из трех величайших живописцев Фланд...
# 12016  {'ru': '<p>Лекцию читает научный сотрудник ГМИ...
# 12067  {'ru': '<p>Лекцию читает научный сотрудник ГМИ...
# 12047  {'ru': '<p>Лекцию читает кандидат искусствовед...
# 12175  {'ru': '<p>Лауреаты российских и международных...
# 12465  {'ru': '<p><strong>Главное здание. Волхонка, 1...
# 12060  {'ru': '<p>Лекцию читает научный сотрудник ГМИ...
# 12086  {'ru': '<p>Лекцию читает преподаватель факульт...
# 12017  {'ru': '<p>Лекцию читает кандидат искусствовед...
# 12068  {'ru': '<p>Лекцию читает научный сотрудник ГМИ...
# 12358  {'ru': '<p><strong>Василий Расторгуев</strong>...
# 12048  {'ru': '<p>Лекцию читает историк искусства Али...
# 12061  {'ru': '<p>Лекцию читает научный сотрудник ГМИ...
# 12087  {'ru': '<p>Лекцию читает фотограф, член фотокл...
# 12018  {'ru': '<p>Лекцию читает кандидат искусствовед...
# 12069  {'ru': '<p>Лекцию читает научный сотрудник ГМИ...
# 12049  {'ru': '<p>Лекцию читает научный сотрудник ГМИ...
#
#                                 ticket  \
# 11421                        /#sid=685
# 11540                   /#id=1&sid=282
# 11468                    /#id=1&sid=61
# 12173  /tickets/37083/28.09.2019/18:00
# 12040                    /#id=1&sid=61
# 12084
# 12426  /tickets/37739/01.10.2019/19:00
# 12015
# 12463  /tickets/37800/02.10.2019/19:00
# 12065
# 12066
# 12464  /tickets/37801/03.10.2019/19:00
# 12046
# 12438
# 12442
# 12466
# 12174  /tickets/37085/06.10.2019/18:00
# 12058
# 12059
# 12085
# 12357  /tickets/37479/08.10.2019/19:00
# 12016
# 12067
# 12047
# 12175  /tickets/37086/11.10.2019/19:00
# 12465
# 12060
# 12086
# 12017
# 12068
# 12358  /tickets/37480/17.10.2019/19:00
# 12048
# 12061
# 12087
# 12018
# 12069
# 12049
#
#                                                     type  \
# 11421             {'ru': 'Выставка', 'en': 'Exhibition'}
# 11540                 {'ru': 'Концерт', 'en': 'Concert'}
# 11468             {'ru': 'Выставка', 'en': 'Exhibition'}
# 12173                 {'ru': 'Концерт', 'en': 'Concert'}
# 12040             {'ru': 'Выставка', 'en': 'Exhibition'}
# 12084                  {'ru': 'Лекция', 'en': 'Lection'}
# 12426                  {'ru': 'Лекция', 'en': 'Lection'}
# 12015                  {'ru': 'Лекция', 'en': 'Lection'}
# 12463                  {'ru': 'Лекция', 'en': 'Lection'}
# 12065  {'ru': 'Лекционный абонемент', 'en': 'Lection ...
# 12066                  {'ru': 'Лекция', 'en': 'Lection'}
# 12464  {'ru': 'Встреча с куратором', 'en': 'Meet the ...
# 12046                  {'ru': 'Лекция', 'en': 'Lection'}
# 12438  {'ru': 'Пятницы в Пушкинском', 'en': 'Fridays ...
# 12442  {'ru': 'Пятницы в Пушкинском', 'en': 'Fridays ...
# 12466  {'ru': 'Мероприятие «Объединения выпускников»'...
# 12174                 {'ru': 'Концерт', 'en': 'Concert'}
# 12058  {'ru': 'Лекционный абонемент', 'en': 'Lection ...
# 12059                  {'ru': 'Лекция', 'en': 'Lection'}
# 12085                  {'ru': 'Лекция', 'en': 'Lection'}
# 12357                  {'ru': 'Лекция', 'en': 'Lection'}
# 12016                  {'ru': 'Лекция', 'en': 'Lection'}
# 12067                  {'ru': 'Лекция', 'en': 'Lection'}
# 12047                  {'ru': 'Лекция', 'en': 'Lection'}
# 12175                 {'ru': 'Концерт', 'en': 'Concert'}
# 12465  {'ru': 'Пятницы в Пушкинском', 'en': 'Fridays ...
# 12060                  {'ru': 'Лекция', 'en': 'Lection'}
# 12086                  {'ru': 'Лекция', 'en': 'Lection'}
# 12017                  {'ru': 'Лекция', 'en': 'Lection'}
# 12068                  {'ru': 'Лекция', 'en': 'Lection'}
# 12358           {'ru': 'Экскурсия', 'en': 'Guided tour'}
# 12048                  {'ru': 'Лекция', 'en': 'Lection'}
# 12061                  {'ru': 'Лекция', 'en': 'Lection'}
# 12087                  {'ru': 'Лекция', 'en': 'Lection'}
# 12018                  {'ru': 'Лекция', 'en': 'Lection'}
# 12069                  {'ru': 'Лекция', 'en': 'Lection'}
# 12049                  {'ru': 'Лекция', 'en': 'Lection'}
#
#                                                   within
# 11421  {'0': {'id': 11869, 'name': {'ru': 'История со...
# 11540  {'0': {'id': 11452, 'name': {'ru': 'Александр ...
# 11468  {'0': {'id': 12354, 'name': {'ru': 'Кураторска...
# 12173
# 12040  {'0': {'id': 12463, 'name': {'ru': 'Икаты Маве...
# 12084
# 12426
# 12015
# 12463
# 12065  {'0': {'id': 12066, 'name': {'ru': 'Эдуард Ман...
# 12066
# 12464
# 12046
# 12438  {'0': {'id': 12442, 'name': {'ru': 'Пятница в ...
# 12442
# 12466
# 12174
# 12058  {'0': {'id': 12059, 'name': {'ru': None, 'en':...
# 12059
# 12085
# 12357
# 12016
# 12067
# 12047
# 12175
# 12465
# 12060
# 12086
# 12017
# 12068
# 12358
# 12048
# 12061
# 12087
# 12018
# 12069
# 12049
#
# [37 rows x 29 columns]
